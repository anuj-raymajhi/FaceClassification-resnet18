# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
class ResNetModel:
    def __init__(self, input_shape, num_classes):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.model = self.build_model()

    def build_model(self):
        inputs = layers.Input(shape=self.input_shape)

        x = layers.Conv2D(64, kernel_size=7, strides=2, padding='same')(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

        filters = [64, 128, 256, 512]
        num_blocks = [2, 2, 2, 2]

        for i in range(len(filters)):
            for j in range(num_blocks[i]):
                if j == 0 and i != 0:
                    x = self.residual_block(x, filters[i], stride=2)
                else:
                    x = self.residual_block(x, filters[i])

        x = layers.GlobalAveragePooling2D()(x)
        x = layers.Dense(self.num_classes, activation='softmax')(x)

        model = models.Model(inputs, x)
        return model

    def residual_block(self, x, filters, kernel_size=3, stride=1, activation='relu'):
        shortcut = x

        x = layers.Conv2D(filters, kernel_size, strides=stride, padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation(activation)(x)

        x = layers.Conv2D(filters, kernel_size, strides=1, padding='same')(x)
        x = layers.BatchNormalization()(x)

        if stride != 1 or shortcut.shape[-1] != filters:
            shortcut = layers.Conv2D(filters, kernel_size=1, strides=stride, padding='same')(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)

        x = layers.add([x, shortcut])
        x = layers.Activation(activation)(x)

        return x
    
    def compile_model(self, optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']):
        self.model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    def train(self, X_train, y_train, X_val, y_val, batch_size=32, epochs=10):
        train_steps_per_epoch = len(X_train) // batch_size
        val_steps_per_epoch = len(X_val) // batch_size

        for epoch in range(epochs):
            print(f"Epoch {epoch + 1}/{epochs}")

            # Training
            train_loss = 0
            train_accuracy = 0
            for step in range(train_steps_per_epoch):
                batch_X = X_train[step * batch_size:(step + 1) * batch_size]
                batch_y = y_train[step * batch_size:(step + 1) * batch_size]

                loss, accuracy = self.model.train_on_batch(batch_X, batch_y)
                train_loss += loss
                train_accuracy += accuracy

            train_loss /= train_steps_per_epoch
            train_accuracy /= train_steps_per_epoch

            # Validation
            val_loss = 0
            val_accuracy = 0
            for step in range(val_steps_per_epoch):
                batch_X = X_val[step * batch_size:(step + 1) * batch_size]
                batch_y = y_val[step * batch_size:(step + 1) * batch_size]

                loss, accuracy = self.model.test_on_batch(batch_X, batch_y)
                val_loss += loss
                val_accuracy += accuracy

            val_loss /= val_steps_per_epoch
            val_accuracy /= val_steps_per_epoch

            print(f"Train Loss: {train_loss:.4f} - Train Accuracy: {train_accuracy:.4f} - "
                  f"Val Loss: {val_loss:.4f} - Val Accuracy: {val_accuracy:.4f}")

    def predict(self, X):
        return self.model.predict(X)
    def save_model(self, filepath):
        return self.model.save(filepath)

# %%
dataset = np.load('faceClassificationDataset.npz')

# %%
X, y, labels = dataset['X'], dataset['y'], dataset['labels']

# %%
X.shape
# Out:
# (9164, 224, 224, 3)

# %%
prep = list(zip(X,y))
np.random.shuffle(prep)

# %%
X, y = zip(*prep)

# %%
X = np.array(X)
y = np.array(y)

# %%
X.shape
# Out:
# (9164, 224, 224, 3)

# %%
trainSize = int(0.8*len(X))

X_train, X_val = X[:trainSize], X[trainSize:]
y_train, y_val = y[:trainSize], y[trainSize:]

# One-hot encode the labels
num_classes = len(labels)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_val = tf.keras.utils.to_categorical(y_val, num_classes)

# # Ensure correct data types
# X_train = X_train.astype(np.float32)
# X_val = X_val.astype(np.float32)
# y_train = y_train.astype(np.float32)
# y_val = y_val.astype(np.float32)

# %%
input_shape = (224, 224, 3)

model = ResNetModel(input_shape, num_classes)
model.compile_model()
model.train(X_train, y_train, X_val, y_val, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# Train Loss: 7.1073 - Train Accuracy: 0.0575 - Val Loss: 32.4997 - Val Accuracy: 0.0543
# Epoch 2/100
# Train Loss: 6.6639 - Train Accuracy: 0.0585 - Val Loss: 35.9280 - Val Accuracy: 0.0285
# Epoch 3/100
# Train Loss: 6.4557 - Train Accuracy: 0.0584 - Val Loss: 7.3210 - Val Accuracy: 0.0592
# Epoch 4/100
# Train Loss: 6.0939 - Train Accuracy: 0.0667 - Val Loss: 7.0356 - Val Accuracy: 0.0620
# Epoch 5/100
# Train Loss: 5.6458 - Train Accuracy: 0.0811 - Val Loss: 6.7873 - Val Accuracy: 0.0757
# Epoch 6/100
# Train Loss: 5.1675 - Train Accuracy: 0.1010 - Val Loss: 8.0232 - Val Accuracy: 0.0768
# Epoch 7/100
# Train Loss: 4.6497 - Train Accuracy: 0.1262 - Val Loss: 9.1449 - Val Accuracy: 0.0548
# Epoch 8/100
# Train Loss: 4.1217 - Train Accuracy: 0.1564 - Val Loss: 14.1999 - Val Accuracy: 0.0428
# Epoch 9/100
# Train Loss: 3.6072 - Train Accuracy: 0.2084 - Val Loss: 14.2488 - Val Accuracy: 0.0488
# Epoch 10/100
# Train Loss: 3.0752 - Train Accuracy: 0.2841 - Val Loss: 20.7197 - Val Accuracy: 0.0609
# Epoch 11/100
# Train Loss: 2.5571 - Train Accuracy: 0.3837 - Val Loss: 13.2082 - Val Accuracy: 0.0981
# Epoch 12/100
# Train Loss: 2.0353 - Train Accuracy: 0.5044 - Val Loss: 11.1798 - Val Accuracy: 0.1272
# Epoch 13/100
# Train Loss: 1.5307 - Train Accuracy: 0.6347 - Val Loss: 10.4047 - Val Accuracy: 0.1277
# Epoch 14/100
# Train Loss: 1.0754 - Train Accuracy: 0.7500 - Val Loss: 8.5624 - Val Accuracy: 0.1595
# Epoch 15/100
# Train Loss: 0.6744 - Train Accuracy: 0.8652 - Val Loss: 8.5656 - Val Accuracy: 0.1590
# Epoch 16/100
# Train Loss: 0.3803 - Train Accuracy: 0.9390 - Val Loss: 9.6446 - Val Accuracy: 0.1552
# Epoch 17/100
# Train Loss: 0.2069 - Train Accuracy: 0.9753 - Val Loss: 8.7630 - Val Accuracy: 0.2050
# Epoch 18/100
# Train Loss: 0.1219 - Train Accuracy: 0.9889 - Val Loss: 8.7667 - Val Accuracy: 0.2067
# Epoch 19/100
# Train Loss: 0.0739 - Train Accuracy: 0.9943 - Val Loss: 9.3263 - Val Accuracy: 0.2242
# Epoch 20/100
# Train Loss: 0.0588 - Train Accuracy: 0.9934 - Val Loss: 9.2913 - Val Accuracy: 0.2319
# Epoch 21/100
# Train Loss: 0.0454 - Train Accuracy: 0.9952 - Val Loss: 10.3889 - Val Accuracy: 0.2105
# Epoch 22/100
# Train Loss: 0.0418 - Train Accuracy: 0.9960 - Val Loss: 9.5729 - Val Accuracy: 0.2248
# Epoch 23/100
# Train Loss: 0.0321 - Train Accuracy: 0.9977 - Val Loss: 10.1430 - Val Accuracy: 0.2220
# Epoch 24/100
# Train Loss: 0.0424 - Train Accuracy: 0.9939 - Val Loss: 11.0605 - Val Accuracy: 0.1913
# Epoch 25/100
# Train Loss: 0.2937 - Train Accuracy: 0.9174 - Val Loss: 18.1638 - Val Accuracy: 0.1568
# Epoch 26/100
# Train Loss: 0.2527 - Train Accuracy: 0.9305 - Val Loss: 13.6293 - Val Accuracy: 0.1573
# Epoch 27/100
# Train Loss: 0.1223 - Train Accuracy: 0.9708 - Val Loss: 11.0803 - Val Accuracy: 0.2018
# Epoch 28/100
# Train Loss: 0.0735 - Train Accuracy: 0.9828 - Val Loss: 10.6225 - Val Accuracy: 0.2116
# Epoch 29/100
# Train Loss: 0.0653 - Train Accuracy: 0.9870 - Val Loss: 10.4950 - Val Accuracy: 0.2083
# Epoch 30/100
# Train Loss: 0.0517 - Train Accuracy: 0.9872 - Val Loss: 10.8288 - Val Accuracy: 0.2275
# Epoch 31/100
# Train Loss: 0.0581 - Train Accuracy: 0.9861 - Val Loss: 12.8106 - Val Accuracy: 0.2083
# Epoch 32/100
# Train Loss: 0.1057 - Train Accuracy: 0.9742 - Val Loss: 12.1663 - Val Accuracy: 0.2023
# Epoch 33/100
# Train Loss: 0.1229 - Train Accuracy: 0.9649 - Val Loss: 12.3644 - Val Accuracy: 0.1941
# Epoch 34/100
# Train Loss: 0.0847 - Train Accuracy: 0.9754 - Val Loss: 17.2859 - Val Accuracy: 0.1902
# Epoch 35/100
# Train Loss: 0.0980 - Train Accuracy: 0.9748 - Val Loss: 13.2956 - Val Accuracy: 0.2116
# Epoch 36/100
# Train Loss: 0.0956 - Train Accuracy: 0.9722 - Val Loss: 13.8264 - Val Accuracy: 0.1913
# Epoch 37/100
# Train Loss: 0.0727 - Train Accuracy: 0.9805 - Val Loss: 11.7015 - Val Accuracy: 0.2105
# Epoch 38/100
# Train Loss: 0.0668 - Train Accuracy: 0.9805 - Val Loss: 11.2466 - Val Accuracy: 0.2281
# Epoch 39/100
# Train Loss: 0.0756 - Train Accuracy: 0.9801 - Val Loss: 12.8740 - Val Accuracy: 0.1935
# Epoch 40/100
# Train Loss: 0.0748 - Train Accuracy: 0.9794 - Val Loss: 11.6164 - Val Accuracy: 0.2160
# Epoch 41/100
# Train Loss: 0.0882 - Train Accuracy: 0.9773 - Val Loss: 12.1974 - Val Accuracy: 0.1974
# Epoch 42/100
# Train Loss: 0.0656 - Train Accuracy: 0.9819 - Val Loss: 10.8546 - Val Accuracy: 0.2484
# Epoch 43/100
# Train Loss: 0.0462 - Train Accuracy: 0.9862 - Val Loss: 11.2037 - Val Accuracy: 0.2275
# Epoch 44/100
# Train Loss: 0.0311 - Train Accuracy: 0.9925 - Val Loss: 10.8364 - Val Accuracy: 0.2456
# Epoch 45/100
# Train Loss: 0.0150 - Train Accuracy: 0.9971 - Val Loss: 9.4298 - Val Accuracy: 0.2851
# Epoch 46/100
# Train Loss: 0.0066 - Train Accuracy: 0.9992 - Val Loss: 9.3609 - Val Accuracy: 0.2878
# Epoch 47/100
# Train Loss: 0.0019 - Train Accuracy: 0.9999 - Val Loss: 9.0967 - Val Accuracy: 0.2977
# Epoch 48/100
# Train Loss: 0.0009 - Train Accuracy: 1.0000 - Val Loss: 9.1266 - Val Accuracy: 0.3070
# Epoch 49/100
# Train Loss: 0.0004 - Train Accuracy: 1.0000 - Val Loss: 9.1085 - Val Accuracy: 0.3065
# Epoch 50/100
# Train Loss: 0.0003 - Train Accuracy: 1.0000 - Val Loss: 9.1084 - Val Accuracy: 0.3081
# Epoch 51/100
# Train Loss: 0.0002 - Train Accuracy: 1.0000 - Val Loss: 9.1086 - Val Accuracy: 0.3087
# Epoch 52/100
# Train Loss: 0.0002 - Train Accuracy: 1.0000 - Val Loss: 9.1094 - Val Accuracy: 0.3087
# Epoch 53/100
# Train Loss: 0.0002 - Train Accuracy: 1.0000 - Val Loss: 9.1109 - Val Accuracy: 0.3087
# Epoch 54/100
# Train Loss: 0.0002 - Train Accuracy: 1.0000 - Val Loss: 9.1132 - Val Accuracy: 0.3087
# Epoch 55/100
# Train Loss: 0.0002 - Train Accuracy: 1.0000 - Val Loss: 9.1159 - Val Accuracy: 0.3092
# Epoch 56/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1190 - Val Accuracy: 0.3081
# Epoch 57/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1227 - Val Accuracy: 0.3087
# Epoch 58/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1267 - Val Accuracy: 0.3092
# Epoch 59/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1314 - Val Accuracy: 0.3092
# Epoch 60/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1363 - Val Accuracy: 0.3098
# Epoch 61/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1418 - Val Accuracy: 0.3098
# Epoch 62/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1479 - Val Accuracy: 0.3103
# Epoch 63/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1543 - Val Accuracy: 0.3114
# Epoch 64/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1612 - Val Accuracy: 0.3103
# Epoch 65/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1686 - Val Accuracy: 0.3098
# Epoch 66/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1764 - Val Accuracy: 0.3103
# Epoch 67/100
# Train Loss: 0.0001 - Train Accuracy: 1.0000 - Val Loss: 9.1848 - Val Accuracy: 0.3098
# Epoch 68/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.1934 - Val Accuracy: 0.3109
# Epoch 69/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.2025 - Val Accuracy: 0.3120
# Epoch 70/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.2123 - Val Accuracy: 0.3125
# Epoch 71/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.2224 - Val Accuracy: 0.3125
# Epoch 72/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.2330 - Val Accuracy: 0.3125
# Epoch 73/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.2439 - Val Accuracy: 0.3136
# Epoch 74/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.2555 - Val Accuracy: 0.3147
# Epoch 75/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.2672 - Val Accuracy: 0.3158
# Epoch 76/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.2796 - Val Accuracy: 0.3163
# Epoch 77/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.2926 - Val Accuracy: 0.3163
# Epoch 78/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.3056 - Val Accuracy: 0.3174
# Epoch 79/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.3192 - Val Accuracy: 0.3180
# Epoch 80/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.3332 - Val Accuracy: 0.3180
# Epoch 81/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.3476 - Val Accuracy: 0.3180
# Epoch 82/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.3624 - Val Accuracy: 0.3180
# Epoch 83/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.3774 - Val Accuracy: 0.3180
# Epoch 84/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.3931 - Val Accuracy: 0.3180
# Epoch 85/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.4087 - Val Accuracy: 0.3180
# Epoch 86/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.4248 - Val Accuracy: 0.3180
# Epoch 87/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.4415 - Val Accuracy: 0.3180
# Epoch 88/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.4584 - Val Accuracy: 0.3180
# Epoch 89/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.4755 - Val Accuracy: 0.3180
# Epoch 90/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.4929 - Val Accuracy: 0.3202
# Epoch 91/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.5105 - Val Accuracy: 0.3207
# Epoch 92/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.5287 - Val Accuracy: 0.3202
# Epoch 93/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.5472 - Val Accuracy: 0.3202
# Epoch 94/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.5658 - Val Accuracy: 0.3202
# Epoch 95/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.5847 - Val Accuracy: 0.3202
# Epoch 96/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.6042 - Val Accuracy: 0.3213
# Epoch 97/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.6236 - Val Accuracy: 0.3218
# Epoch 98/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.6434 - Val Accuracy: 0.3218
# Epoch 99/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.6635 - Val Accuracy: 0.3224
# Epoch 100/100
# Train Loss: 0.0000 - Train Accuracy: 1.0000 - Val Loss: 9.6840 - Val Accuracy: 0.3224
